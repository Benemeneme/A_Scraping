# %%
import bs4
import urllib3

# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
#waehlen der url
my_url = 'https://www.amazon.de/s?k=fimo&__mk_de_DE=%C3%85M%C3%85%C5%BD%C3%95%C3%91&ref=nb_sb_noss_1'
#https://www.amazon.de/s?k=fimo&page=2&__mk_de_DE=%C3%85M%C3%85%C5%BD%C3%95%C3%91&qid=1575290591&ref=sr_pg_2

# %%
my_url
# Out:
# 'https://www.amazon.de/s?k=fimo&__mk_de_DE=%C3%85M%C3%85%C5%BD%C3%95%C3%91&ref=nb_sb_noss_1'

# %%
#open connection crab page
uClient = uReq(my_url)

# %%
page_html = uClient.read()

# %%
#close connection
uClient.close()

# %%
#parsing der html datei
page_soup = soup(page_html, "html.parser")

# %%
#ausgeben der ueberschrift
page_soup
#page_soup.h1
# Out:
# <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="de-de"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/><link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/><link href="https://m.media-amazon.com" rel="dns-prefetch"/><link href="https://completion.amazon.com" rel="dns-prefetch"/><!-- sp:feature:aui-assets -->
# ...

# %%
page_soup.p
# Out:
# <p class="nav_p nav-bold">Momentanes Problem beim Laden dieses Menüs.</p>

# %%
#holt den ganzen body aus dem html
page_soup.body
# Out:
# <body class="a-m-de a-aui_152852-c a-aui_157141-c a-aui_158613-t1 a-aui_72554-c a-aui_dropdown_187959-c a-aui_pci_risk_banner_210084-c a-aui_perf_130093-c a-aui_tnr_v2_180836-c a-aui_ux_145937-c"><div id="a-page"><script data-a-state='{"key":"a-wlab-states"}' type="a-state">{"AUI_157141":"C","AUI_152852":"C","AUI_TNR_V2_180836":"C","AUI_UX_145937":"C","AUI_158613":"T1","AUI_72554":"C","AUI_DROPDOWN_187959":"C","AUI_PCI_RISK_BANNER_210084":"C","AUI_PERF_130093":"C"}</script><script>typeof uex === 'function' && uex('ld', 'portal-bb', {wb: 1})</script><!-- sp:feature:nav-inline-js -->
# <!-- From remote config v3-->
# <script type="text/javascript">
# ...

# %%
#holt alle p also texte aus den html
h2_soup = page_soup.findAll("h2",{})
h2_soup
# Out:
# [<h2 class="a-size-mini a-spacing-none a-color-base s-line-clamp-2">
#  <a class="a-link-normal a-text-normal" href="/ofenh%C3%A4rtende-Modelliermasse-Kartonetui-sortierten-Basic-Farben/dp/B07N7H98HX">
#  <span class="a-size-medium a-color-base a-text-normal">FIMO soft ofenhärtende Modelliermasse. Kartonetui mit 12 sortierten Basic-Farben.</span>
#  </a>
#  </h2>, <h2 class="a-size-mini a-spacing-none a-color-base s-line-clamp-2">
#  <a class="a-link-normal a-text-normal" href="/Staedtler-FIMO-ofenh%C3%A4rtende-Modelliermasse-Gro%C3%9Fblock/dp/B07NLQQBCP">
#  <span class="a-size-medium a-color-base a-text-normal">Staedtler FIMO soft ofenhärtende Modelliermasse, Großblock 454g (1 lb), weiß</span>
#  </a>
#  </h2>, <h2 class="a-size-mini a-spacing-none a-color-base s-line-clamp-2">
#  <a class="a-link-normal a-text-normal" href="/Staedtler-8023-02-Colour-24x25g/dp/B000LLMX62">
# ...

# %%
#holt alle überschriften h3 mit dem zusatz class = "subheading" aus dem text
page_find_all = page_soup.findAll("a", {"class":"a-link-normal a-text-normal"})

# %%
containers = page_soup.findAll("div", {"class": "a-section a-spacing-none a-spacing-top-small"})
containers
# Out:
# [<div class="a-section a-spacing-none a-spacing-top-small">
#  <div class="a-row a-size-base a-color-base"><div class="a-row">
#  <a class="a-size-base a-link-normal s-no-hover a-text-normal" href="/ofenh%C3%A4rtende-Modelliermasse-Kartonetui-sortierten-Basic-Farben/dp/B07N7H98HX">
#  <span class="a-price" data-a-color="base" data-a-size="l"><span class="a-offscreen">11,16 €</span><span aria-hidden="true"><span class="a-price-whole">11,16</span><span class="a-price-symbol">€</span></span></span>
#  <span class="a-price a-text-price" data-a-color="secondary" data-a-size="b" data-a-strike="true"><span class="a-offscreen">11,32 €</span><span aria-hidden="true">11,32€</span></span>
#  </a>
#  <span class="a-letter-space"></span></div></div>
#  </div>, <div class="a-section a-spacing-none a-spacing-top-small">
#  <div class="a-row a-size-base a-color-base"><div class="a-row">
# ...

# %%
page_find_link = page_soup.findAll("a", {"class":"a-link-normal a-text-normal"})
cont_text2 =""
for container in containers:
    cont_text = container.div.select("a")
    #for anker in cont_text("a"):
        #print("HREF:", dict(anker.attrs).get("href"))
    #print("HREF:", dict(container.div.select("a").attrs).get("href"))    
    cont_text2 = cont_text2 + str(cont_text)  
    #print(cont_text)
cont_text2
# Out:
# '[<a class="a-size-base a-link-normal s-no-hover a-text-normal" href="/ofenh%C3%A4rtende-Modelliermasse-Kartonetui-sortierten-Basic-Farben/dp/B07N7H98HX">\n<span class="a-price" data-a-color="base" data-a-size="l"><span class="a-offscreen">11,16\xa0€</span><span aria-hidden="true"><span class="a-price-whole">11,16</span><span class="a-price-symbol">€</span></span></span>\n<span class="a-price a-text-price" data-a-color="secondary" data-a-size="b" data-a-strike="true"><span class="a-offscreen">11,32\xa0€</span><span aria-hidden="true">11,32€</span></span>\n</a>][<a class="a-size-base a-link-normal s-no-hover a-text-normal" href="/Staedtler-FIMO-ofenh%C3%A4rtende-Modelliermasse-Gro%C3%9Fblock/dp/B07NLQQBCP">\n<span class="a-price" data-a-color="base" data-a-size="l"><span class="a-offscreen">12,78\xa0€</span><span aria-hidden="true"><span class="a-price-whole">12,78</span><span class="a-price-symbol">€</span></span></span>\n<span class="a-size-base a-color-secondary">(37,37\xa0€/kg)</s
# ...

# %%
#headlines speichern
headlines = page_soup.findAll("h3", {"class":"subheading"})
#anzahl der headlines zählen
len(page_soup.findAll("h3", {"class":"subheading"}))
# Out:
# 0

# %%
headlines[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-a357c03350ef> in <module>
# ----> 1 headlines[0]
#
# IndexError: list index out of range

# %%
text_prod = page_soup.findAll("span", {"class":"a-size-medium a-color-base a-text-normal"})
len(page_find_all)
# Out:
# 16

# %%
text_prod
# Out:
# [<span class="a-size-medium a-color-base a-text-normal">FIMO soft ofenhärtende Modelliermasse. Kartonetui mit 12 sortierten Basic-Farben.</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Staedtler FIMO soft ofenhärtende Modelliermasse, Großblock 454g (1 lb), weiß</span>,
#  <span class="a-size-medium a-color-base a-text-normal">FIMO soft ofenhärtende Modelliermasse. Kartonetui mit 24 sortierten Basic-Farben, 24 Halbblöcke à 25 g</span>,
#  <span class="a-size-medium a-color-base a-text-normal">ESANDA Polymer Clay, 46 Blöcke, farbige Modelliermasse, DIY Soft Craft Clay Set mit Modellierwerkzeugen und Zubehör in Aufbewahrungsbox, bestes Geschenk für Kinder (46 Blöcke, Gewicht 1,9 kg)</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Staedtler FIMO 12er Materialpackung + Werkzeuge Set inkl. BONUS</span>,
# ...

# %%
for text in text_prod:
    print(text)
# Out:
# <span class="a-size-medium a-color-base a-text-normal">FIMO soft ofenhärtende Modelliermasse. Kartonetui mit 12 sortierten Basic-Farben.</span>
# <span class="a-size-medium a-color-base a-text-normal">Staedtler FIMO soft ofenhärtende Modelliermasse, Großblock 454g (1 lb), weiß</span>
# <span class="a-size-medium a-color-base a-text-normal">FIMO soft ofenhärtende Modelliermasse. Kartonetui mit 24 sortierten Basic-Farben, 24 Halbblöcke à 25 g</span>
# <span class="a-size-medium a-color-base a-text-normal">ESANDA Polymer Clay, 46 Blöcke, farbige Modelliermasse, DIY Soft Craft Clay Set mit Modellierwerkzeugen und Zubehör in Aufbewahrungsbox, bestes Geschenk für Kinder (46 Blöcke, Gewicht 1,9 kg)</span>
# <span class="a-size-medium a-color-base a-text-normal">Staedtler FIMO 12er Materialpackung + Werkzeuge Set inkl. BONUS</span>
# ...

# %%
#href_link = ""
for anker in page_soup("a", {"class":"a-link-normal a-text-normal"}):
    print ("TEXT:", anker.string)
    print ("HREF:", dict(anker.attrs).get("href"))
    href_link = dict(anker.attrs).get("href")
    #print "text:  ", dict(anker.attrs).get("id")
    #page_soup
# Out:
# TEXT: None
# HREF: /ofenh%C3%A4rtende-Modelliermasse-Kartonetui-sortierten-Basic-Farben/dp/B07N7H98HX
# TEXT: None
# HREF: /Staedtler-FIMO-ofenh%C3%A4rtende-Modelliermasse-Gro%C3%9Fblock/dp/B07NLQQBCP
# TEXT: None
# HREF: /Staedtler-8023-02-Colour-24x25g/dp/B000LLMX62
# TEXT: None
# HREF: /Knetmasse-Handwerk-Modellierwerkzeugen-Aufbewahrungsbox-Farben%EF%BC%8C1-5KG/dp/B07FVH584G
# TEXT: None
# HREF: /Staedtler-Materialpackung-Werkzeuge-inkl-BONUS/dp/B0176GFS1G
# TEXT: None
# HREF: /Knete-Soft-Set-Weihnachten-Geburtstagsgeschenke/dp/B07KWR66CR
# TEXT: None
# HREF: /Staedtler-8101-0-Modelliermasse-Fimo-basic/dp/B000KSJCJW
# TEXT: None
# HREF: /ofenh%C3%A4rtende-Modelliermasse-Kartonetui-sortierten-Pastell-Farben/dp/B07N7K954L
# TEXT: None
# HREF: /Vindany-Polymer-Clay-Kinderknete-Modeling/dp/B07Q3VNXCX
# TEXT: None
# HREF: /Staedtler-8034-kinderleichte-wiederverschlie%C3%9Fbare-Modellierstab/dp/B00INK36GO
# TEXT: None
# HREF: /Fimo-Starter-Multicolour-Blocks-Steadtler/dp/B00QHE98VK
# ...

# %%
text_next = page_soup.findAll("li", {"class":"a-normal"})
text_next
##hier zusatz ein Get from url befehl über python um crawler schutz zu deaktivieren
# Out:
# [<li class="a-normal"><a href="/fimo/s?k=fimo&amp;page=2">2</a></li>,
#  <li class="a-normal"><a href="/fimo/s?k=fimo&amp;page=3">3</a></li>]

# %%
len(href_link)
# Out:
# 69

# %%
href_link
# Out:
# '/STAEDTLER-8013-Effect-ofenh%C3%A4rtende-Modelliermasse/dp/B07N85XGL4'

# %%
nuname = href_link[len(href_link)-10:len(href_link)]
nuname
# Out:
# 'B07N85XGL4'

# %%
file_name = "amazone_test_links1-2.csv"
f = open(file_name, "w", encoding='utf8')

headers = "name;link\n"

f.write(headers)

#a = 0
#for feed_all in feeds_all:
#while a < 93:
    #text_feeds_all = feeds_all[a].text
    #text_head_all = head_all[a].text
    #text_string = head_all[a].text + ";" + feeds_all[a].text + "\n"
    #f.write(text_string)
    #a=a+1
    
    
   ##get prod name 
for anker in page_soup("a", {"class":"a-link-normal a-text-normal"}):
    #print ("TEXT:", anker.string)
    #print ("HREF:", dict(anker.attrs).get("href"))
    #href_link = dict(anker.attrs).get("href")
    naname = dict(anker.attrs).get("href")
    prod_naname = naname[1:len(naname)-14]
    prod_naid = naname[len(naname)-10:len(naname)]
    f.write(prod_naname + ";"+prod_naid+ "\n")
    #f.write(dict(anker.attrs).get("href") + "\n")
    #f.write(dict(anker.attrs).get("href")[len(dict(anker.attrs).get("href"))-10:len(dict(anker.attrs).get("href")] + "\n")
   
    #a=95
#while a < len(feeds_all):
    #text_feeds_all = feeds_all[a].text
    #text_head_all = head_all[a].text
    #f.write(head_all[a].text + ";" + feeds_all[a].text + "\n")
    #a=a+1   
#f.write(text_head_all + ";" + text_feeds_all + "\n")
f.close()
